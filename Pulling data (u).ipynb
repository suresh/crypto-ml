# %% [markdown]
# The code used to originally pull the raw data from exchanges.

# %%
import ccxt
import pandas as pd
import statistics as stat
from math import pi
import time
import random
import os

#plotting
from bokeh.plotting import figure, show, output_file
from bokeh.io import output_notebook
from bokeh.models import Axis
from bokeh.layouts import gridplot
from bokeh.plotting import figure

# %%
def create_ohlcv_df(data):
    header = ['Timestamp', 'Open', 'High', 'Low', 'Close', 'Volume']
    df = pd.DataFrame(data, columns=header)
    df['Timestamp'] = pd.to_datetime(df['Timestamp'],unit='ms',origin='unix') # convert timestamp to datetime
    return df

# %%
# pulls "n_candles" number of candles with "c_size" candlesticks from a given start date
# for all symbol pairs on a given exchange and stores them in a pandas dataframe, 
# then saves them in csv's in the specified folder path
# returns a list with the symbols it could not fetch

# -- EXAMPLE INPUT --
# exchange = 'bittrex'
# from_date = '2018-04-20 00:00:00'
# n_candles = 480
# c_size = '1h'
# f_path = '../data'

def pull_data(exchange,from_date,n_candles,c_size,f_path,skip=False):
    count = 1
    msec = 1000
    hold = 30
    
    missing_symbols = []

    # -- create a folder --
    newpath = f_path+'/'+exchange+'/'
    if not os.path.exists(newpath):
        os.makedirs(newpath)

    # -- load exchange --
    exc_instance = getattr(ccxt,exchange)()
    exc_instance.load_markets()
    from_timestamp = exc_instance.parse8601(from_date)
    
    # -- pull ohlcv --
    for symbol in exc_instance.symbols:
        for attempt in range(5): # 5 attempts max
            try:
                print('Pulling:',exchange,':',symbol, '[{}/{}]'.format(count,len(exc_instance.symbols)))
                data = exc_instance.fetch_ohlcv(symbol, c_size, from_timestamp, n_candles)
                
                # if < n_candles returned, skip this pair
                if len(data) < n_candles and skip is True:
                    continue
                
                # -- create DF --
                df = create_ohlcv_df(data)

                # -- save CSV --
                symbol = symbol.replace("/","-")
                filename = newpath+'{}_{}_[{}]-TO-[{}].csv'.format(exchange, symbol, df['Timestamp'].iloc[0], df['Timestamp'].iloc[-1])        
                df.to_csv(filename)
                
            except (ccxt.ExchangeError, ccxt.AuthenticationError, ccxt.ExchangeNotAvailable, ccxt.RequestTimeout, IndexError) as error:
                print('Got an error', type(error).__name__, error.args, ', retrying in', hold, 'seconds...')
                time.sleep(hold)
            else: # if no error, proceed to next iteration
                break
        else: # we failed all attempts
            print('All attempts failed, skipping:',symbol)
            missing_symbols.append(symbol)
            continue
            
        count += 1   
        # -- wait for rate limit --
        time.sleep((exc_instance.rateLimit / msec) + 5) # rate limit +5 seconds to just to be safe

    # print out any symbols we could not obtain
    if len(missing_symbols) is not 0:
        print('Unable to obtain:',missing_symbols)
    
    
    return missing_symbols

# %%
# gets the symbols from a given "exchange", filtering out any symbol pairs provided in "without", and stores in a df
# additionally, if set to save and given a filepath, will save as .csv

# f_path = '../symbols'
def symbol_list_df(exchange, without=[], save=False, f_path=''):

    # -- load market --
    exc_instance = getattr(ccxt, exchange)()
    exc_instance.load_markets()
    
    # -- filter list --
    symbol_list = [s for s in exc_instance.symbols if s not in without]
    
    # -- save --
    if save is True:
      
        # -- create a folder --
        newpath = f_path+'/'
        if not os.path.exists(newpath):
            os.makedirs(newpath)
        
        # -- create df --
        header = ['Symbols']
        df = pd.DataFrame(symbol_list, columns=header)
        filename = newpath+'{}_symbols.csv'.format(exchange)        
        df.to_csv(filename)
            
    return symbol_list

# %%
from_date = '2018-04-20 00:00:00'
exchanges = ['bittrex','binance','kraken','kucoin','lbank']

for e in exchanges:
    pull_data(e,from_date,480,'1h','../data')
# Out:
# Pulling: bittrex : 2GIVE/BTC [1/279]
# Pulling: bittrex : ABY/BTC [2/279]
# Pulling: bittrex : ADA/BTC [3/279]
# Pulling: bittrex : ADA/ETH [4/279]
# Pulling: bittrex : ADA/USDT [5/279]
# Pulling: bittrex : ADT/BTC [6/279]
# Pulling: bittrex : ADT/ETH [7/279]
# Pulling: bittrex : ADX/BTC [8/279]
# Pulling: bittrex : ADX/ETH [9/279]
# Pulling: bittrex : AEON/BTC [10/279]
# Pulling: bittrex : AMP/BTC [11/279]
# Pulling: bittrex : ANT/BTC [12/279]
# Pulling: bittrex : ANT/ETH [13/279]
# Pulling: bittrex : ARDR/BTC [14/279]
# Pulling: bittrex : ARK/BTC [15/279]
# Pulling: bittrex : AUR/BTC [16/279]
# Pulling: bittrex : BAT/BTC [17/279]
# Pulling: bittrex : BAT/ETH [18/279]
# Pulling: bittrex : BAY/BTC [19/279]
# Pulling: bittrex : BCH/BTC [20/279]
# Pulling: bittrex : BCH/ETH [21/279]
# Pulling: bittrex : BCH/USDT [22/279]
# Pulling: bittrex : BCPT/BTC [23/279]
# Pulling: bittrex : BCPT/ETH [24/279]
# Pulling: bittrex : BCY/BTC [25/279]
# Pulling: bittrex : BITB/BTC [26/279]
# Pulling: bittrex : BLITZ/BTC [27/279]
# Pulling: bittrex : BLK/BTC [28/279]
# Pulling: bittrex : BLOCK/BTC [29/279]
# Pulling: bittrex : BLT/BTC [30/279]
# Pulling: bittrex : BLT/ETH [31/279]
# Pulling: bittrex : BNT/BTC [32/279]
# Pulling: bittrex : BNT/ETH [33/279]
# Pulling: bittrex : BRK/BTC [34/279]
# Pulling: bittrex : BRX/BTC [35/279]
# Pulling: bittrex : BSD/BTC [36/279]
# Pulling: bittrex : BTC/USDT [37/279]
# Pulling: bittrex : BTG/BTC [38/279]
# Pulling: bittrex : BTG/ETH [39/279]
# Pulling: bittrex : BTG/USDT [40/279]
# Got an error RequestTimeout ("bittrex GET https://bittrex.com/api/v2.0/pub/market/GetTicks?tickInterval=hour&marketName=USDT-BTG HTTPSConnectionPool(host='bittrex.com', port=443): Read timed out. (read timeout=10)",) , retrying in 30 seconds...
# Pulling: bittrex : BTG/USDT [40/279]
# Pulling: bittrex : BURST/BTC [41/279]
# Pulling: bittrex : BYC/BTC [42/279]
# Pulling: bittrex : CANN/BTC [43/279]
# Pulling: bittrex : CFI/BTC [44/279]
# Pulling: bittrex : CFI/ETH [45/279]
# Pulling: bittrex : CLAM/BTC [46/279]
# Pulling: bittrex : CLOAK/BTC [47/279]
# Pulling: bittrex : COVAL/BTC [48/279]
# Pulling: bittrex : CRB/BTC [49/279]
# Pulling: bittrex : CRB/ETH [50/279]
# Pulling: bittrex : CRW/BTC [51/279]
# Pulling: bittrex : CURE/BTC [52/279]
# Pulling: bittrex : CVC/BTC [53/279]
# Pulling: bittrex : CVC/ETH [54/279]
# Pulling: bittrex : DASH/BTC [55/279]
# Pulling: bittrex : DASH/ETH [56/279]
# Pulling: bittrex : DASH/USDT [57/279]
# Pulling: bittrex : DCR/BTC [58/279]
# Pulling: bittrex : DCT/BTC [59/279]
# Pulling: bittrex : DGB/BTC [60/279]
# Pulling: bittrex : DGB/ETH [61/279]
# Got an error RequestTimeout ("bittrex GET https://bittrex.com/api/v2.0/pub/market/GetTicks?tickInterval=hour&marketName=ETH-DGB HTTPSConnectionPool(host='bittrex.com', port=443): Read timed out. (read timeout=10)",) , retrying in 30 seconds...
# Pulling: bittrex : DGB/ETH [61/279]
# Pulling: bittrex : DMD/BTC [62/279]
# Pulling: bittrex : DMT/BTC [63/279]
# Got an error RequestTimeout ("bittrex GET https://bittrex.com/api/v2.0/pub/market/GetTicks?tickInterval=hour&marketName=BTC-DMT HTTPSConnectionPool(host='bittrex.com', port=443): Read timed out. (read timeout=10)",) , retrying in 30 seconds...
# Pulling: bittrex : DMT/BTC [63/279]
# Pulling: bittrex : DMT/ETH [64/279]
# Pulling: bittrex : DNT/BTC [65/279]
# Pulling: bittrex : DNT/ETH [66/279]
# Pulling: bittrex : DOGE/BTC [67/279]
# Pulling: bittrex : DOPE/BTC [68/279]
# Pulling: bittrex : DTB/BTC [69/279]
# Pulling: bittrex : DYN/BTC [70/279]
# Pulling: bittrex : EBST/BTC [71/279]
# Pulling: bittrex : EDG/BTC [72/279]
# Pulling: bittrex : EFL/BTC [73/279]
# Pulling: bittrex : EGC/BTC [74/279]
# Pulling: bittrex : EMC/BTC [75/279]
# Pulling: bittrex : EMC2/BTC [76/279]
# Pulling: bittrex : ENG/BTC [77/279]
# Pulling: bittrex : ENG/ETH [78/279]
# Pulling: bittrex : ENRG/BTC [79/279]
# Pulling: bittrex : ERC/BTC [80/279]
# Pulling: bittrex : ETC/BTC [81/279]
# Pulling: bittrex : ETC/ETH [82/279]
# Pulling: bittrex : ETC/USDT [83/279]
# Pulling: bittrex : ETH/BTC [84/279]
# Pulling: bittrex : ETH/USDT [85/279]
# Pulling: bittrex : EXCL/BTC [86/279]
# Pulling: bittrex : EXP/BTC [87/279]
# Pulling: bittrex : FCT/BTC [88/279]
# Pulling: bittrex : FCT/ETH [89/279]
# Pulling: bittrex : FLDC/BTC [90/279]
# Pulling: bittrex : FLO/BTC [91/279]
# Pulling: bittrex : FTC/BTC [92/279]
# Pulling: bittrex : GAM/BTC [93/279]
# Pulling: bittrex : GAME/BTC [94/279]
# Pulling: bittrex : GBG/BTC [95/279]
# Pulling: bittrex : GBYTE/BTC [96/279]
# Pulling: bittrex : GEO/BTC [97/279]
# Got an error RequestTimeout ("bittrex GET https://bittrex.com/api/v2.0/pub/market/GetTicks?tickInterval=hour&marketName=BTC-GEO HTTPSConnectionPool(host='bittrex.com', port=443): Read timed out. (read timeout=10)",) , retrying in 30 seconds...
# Pulling: bittrex : GEO/BTC [97/279]
# Pulling: bittrex : GLD/BTC [98/279]
# Pulling: bittrex : GNO/BTC [99/279]
# Pulling: bittrex : GNO/ETH [100/279]
# Pulling: bittrex : GNT/BTC [101/279]
# Pulling: bittrex : GNT/ETH [102/279]
# Pulling: bittrex : GOLOS/BTC [103/279]
# Pulling: bittrex : GRC/BTC [104/279]
# Pulling: bittrex : GRS/BTC [105/279]
# Got an error ExchangeError ('bittrex returned an empty or unrecognized response: {"success":true,"message":"","result":[]}',) , retrying in 30 seconds...
# Pulling: bittrex : GRS/BTC [105/279]
# Pulling: bittrex : GUP/BTC [106/279]
# Pulling: bittrex : GUP/ETH [107/279]
# Pulling: bittrex : HMQ/BTC [108/279]
# Got an error RequestTimeout ("bittrex GET https://bittrex.com/api/v2.0/pub/market/GetTicks?tickInterval=hour&marketName=BTC-HMQ HTTPSConnectionPool(host='bittrex.com', port=443): Read timed out. (read timeout=10)",) , retrying in 30 seconds...
# Pulling: bittrex : HMQ/BTC [108/279]
# Pulling: bittrex : HMQ/ETH [109/279]
# Pulling: bittrex : IGNIS/BTC [110/279]
# Pulling: bittrex : INCNT/BTC [111/279]
# Pulling: bittrex : IOC/BTC [112/279]
# Pulling: bittrex : ION/BTC [113/279]
# Pulling: bittrex : IOP/BTC [114/279]
# Pulling: bittrex : KMD/BTC [115/279]
# Pulling: bittrex : KORE/BTC [116/279]
# Pulling: bittrex : LBC/BTC [117/279]
# Pulling: bittrex : LGD/BTC [118/279]
# Pulling: bittrex : LGD/ETH [119/279]
# Pulling: bittrex : LMC/BTC [120/279]
# Pulling: bittrex : LRC/BTC [121/279]
# Pulling: bittrex : LRC/ETH [122/279]
# Pulling: bittrex : LSK/BTC [123/279]
# Pulling: bittrex : LTC/BTC [124/279]
# Pulling: bittrex : LTC/ETH [125/279]
# Pulling: bittrex : LTC/USDT [126/279]
# Pulling: bittrex : LUN/BTC [127/279]
# Pulling: bittrex : LUN/ETH [128/279]
# Pulling: bittrex : MANA/BTC [129/279]
# Pulling: bittrex : MANA/ETH [130/279]
# Pulling: bittrex : MCO/BTC [131/279]
# Pulling: bittrex : MCO/ETH [132/279]
# Pulling: bittrex : MEME/BTC [133/279]
# Pulling: bittrex : MER/BTC [134/279]
# Pulling: bittrex : MLN/BTC [135/279]
# Pulling: bittrex : MONA/BTC [136/279]
# Pulling: bittrex : MUE/BTC [137/279]
# Pulling: bittrex : MUSIC/BTC [138/279]
# Pulling: bittrex : NAV/BTC [139/279]
# Pulling: bittrex : NBT/BTC [140/279]
# Pulling: bittrex : NEO/BTC [141/279]
# Pulling: bittrex : NEO/ETH [142/279]
# Pulling: bittrex : NEO/USDT [143/279]
# Pulling: bittrex : NEOS/BTC [144/279]
# Pulling: bittrex : NLG/BTC [145/279]
# Pulling: bittrex : NMR/BTC [146/279]
# Pulling: bittrex : NMR/ETH [147/279]
# Pulling: bittrex : NXC/BTC [148/279]
# Pulling: bittrex : NXS/BTC [149/279]
# Pulling: bittrex : NXT/BTC [150/279]
# Pulling: bittrex : NXT/USDT [151/279]
# Got an error RequestTimeout ("bittrex GET https://bittrex.com/api/v2.0/pub/market/GetTicks?tickInterval=hour&marketName=USDT-NXT HTTPSConnectionPool(host='bittrex.com', port=443): Read timed out. (read timeout=10)",) , retrying in 30 seconds...
# Pulling: bittrex : NXT/USDT [151/279]
# Pulling: bittrex : OK/BTC [152/279]
# Pulling: bittrex : OMG/BTC [153/279]
# Pulling: bittrex : OMG/ETH [154/279]
# Pulling: bittrex : OMG/USDT [155/279]
# Pulling: bittrex : OMNI/BTC [156/279]
# Got an error RequestTimeout ("bittrex GET https://bittrex.com/api/v2.0/pub/market/GetTicks?tickInterval=hour&marketName=BTC-OMNI HTTPSConnectionPool(host='bittrex.com', port=443): Read timed out. (read timeout=10)",) , retrying in 30 seconds...
# Pulling: bittrex : OMNI/BTC [156/279]
# Pulling: bittrex : PART/BTC [157/279]
# Pulling: bittrex : PAY/BTC [158/279]
# Pulling: bittrex : PAY/ETH [159/279]
# Got an error RequestTimeout ("bittrex GET https://bittrex.com/api/v2.0/pub/market/GetTicks?tickInterval=hour&marketName=ETH-PAY HTTPSConnectionPool(host='bittrex.com', port=443): Read timed out. (read timeout=10)",) , retrying in 30 seconds...
# Pulling: bittrex : PAY/ETH [159/279]
# Pulling: bittrex : PINK/BTC [160/279]
# Pulling: bittrex : PIVX/BTC [161/279]
# Got an error RequestTimeout ("bittrex GET https://bittrex.com/api/v2.0/pub/market/GetTicks?tickInterval=hour&marketName=BTC-PIVX HTTPSConnectionPool(host='bittrex.com', port=443): Read timed out. (read timeout=10)",) , retrying in 30 seconds...
# Pulling: bittrex : PIVX/BTC [161/279]
# Pulling: bittrex : POLY/BTC [162/279]
# Pulling: bittrex : POLY/ETH [163/279]
# Pulling: bittrex : POT/BTC [164/279]
# Pulling: bittrex : POWR/BTC [165/279]
# Pulling: bittrex : POWR/ETH [166/279]
# Pulling: bittrex : PPC/BTC [167/279]
# Pulling: bittrex : PRO/BTC [168/279]
# Pulling: bittrex : PRO/ETH [169/279]
# Pulling: bittrex : PTC/BTC [170/279]
# Pulling: bittrex : PTOY/BTC [171/279]
# Pulling: bittrex : PTOY/ETH [172/279]
# Pulling: bittrex : QRL/BTC [173/279]
# Pulling: bittrex : QRL/ETH [174/279]
# Pulling: bittrex : QTUM/BTC [175/279]
# Pulling: bittrex : QTUM/ETH [176/279]
# Pulling: bittrex : QWARK/BTC [177/279]
# Pulling: bittrex : RADS/BTC [178/279]
# Pulling: bittrex : RBY/BTC [179/279]
# Pulling: bittrex : RCN/BTC [180/279]
# Pulling: bittrex : RCN/ETH [181/279]
# Pulling: bittrex : RDD/BTC [182/279]
# Pulling: bittrex : REP/BTC [183/279]
# Pulling: bittrex : REP/ETH [184/279]
# Pulling: bittrex : RLC/BTC [185/279]
# Pulling: bittrex : RLC/ETH [186/279]
# Pulling: bittrex : RVR/BTC [187/279]
# Pulling: bittrex : SALT/BTC [188/279]
# Pulling: bittrex : SALT/ETH [189/279]
# Pulling: bittrex : SBD/BTC [190/279]
# Pulling: bittrex : SC/BTC [191/279]
# Pulling: bittrex : SC/ETH [192/279]
# Pulling: bittrex : SC/USDT [193/279]
# Pulling: bittrex : SEQ/BTC [194/279]
# Pulling: bittrex : SHIFT/BTC [195/279]
# Pulling: bittrex : SIB/BTC [196/279]
# Pulling: bittrex : SLR/BTC [197/279]
# Pulling: bittrex : SLS/BTC [198/279]
# Pulling: bittrex : SNRG/BTC [199/279]
# Pulling: bittrex : SNT/BTC [200/279]
# Pulling: bittrex : SNT/ETH [201/279]
# Pulling: bittrex : SPHR/BTC [202/279]
# Pulling: bittrex : SPR/BTC [203/279]
# Pulling: bittrex : SRN/BTC [204/279]
# Pulling: bittrex : SRN/ETH [205/279]
# Pulling: bittrex : STEEM/BTC [206/279]
# Pulling: bittrex : STORJ/BTC [207/279]
# Got an error RequestTimeout ("bittrex GET https://bittrex.com/api/v2.0/pub/market/GetTicks?tickInterval=hour&marketName=BTC-STORJ HTTPSConnectionPool(host='bittrex.com', port=443): Read timed out. (read timeout=10)",) , retrying in 30 seconds...
# Pulling: bittrex : STORJ/BTC [207/279]
# Pulling: bittrex : STORJ/ETH [208/279]
# Pulling: bittrex : STORM/BTC [209/279]
# Pulling: bittrex : STORM/ETH [210/279]
# Pulling: bittrex : STRAT/BTC [211/279]
# Pulling: bittrex : STRAT/ETH [212/279]
# Pulling: bittrex : SWIFT/BTC [213/279]
# Pulling: bittrex : SWT/BTC [214/279]
# Pulling: bittrex : SYNX/BTC [215/279]
# Pulling: bittrex : SYS/BTC [216/279]
# Pulling: bittrex : THC/BTC [217/279]
# Pulling: bittrex : TIX/BTC [218/279]
# Pulling: bittrex : TIX/ETH [219/279]
# Pulling: bittrex : TKS/BTC [220/279]
# Pulling: bittrex : TRST/BTC [221/279]
# Pulling: bittrex : TRST/ETH [222/279]
# Pulling: bittrex : TRUST/BTC [223/279]
# Pulling: bittrex : TRX/BTC [224/279]
# Pulling: bittrex : TRX/ETH [225/279]
# Pulling: bittrex : TRX/USDT [226/279]
# Pulling: bittrex : TUSD/BTC [227/279]
# Pulling: bittrex : TUSD/ETH [228/279]
# Pulling: bittrex : TUSD/USDT [229/279]
# Pulling: bittrex : TX/BTC [230/279]
# Pulling: bittrex : UBQ/BTC [231/279]
# Pulling: bittrex : UKG/BTC [232/279]
# Pulling: bittrex : UKG/ETH [233/279]
# Got an error RequestTimeout ("bittrex GET https://bittrex.com/api/v2.0/pub/market/GetTicks?tickInterval=hour&marketName=ETH-UKG HTTPSConnectionPool(host='bittrex.com', port=443): Read timed out. (read timeout=10)",) , retrying in 30 seconds...
# Pulling: bittrex : UKG/ETH [233/279]
# Pulling: bittrex : UNB/BTC [234/279]
# Pulling: bittrex : UP/BTC [235/279]
# Pulling: bittrex : UP/ETH [236/279]
# Pulling: bittrex : VEE/BTC [237/279]
# Pulling: bittrex : VEE/ETH [238/279]
# Pulling: bittrex : VIA/BTC [239/279]
# Pulling: bittrex : VIB/BTC [240/279]
# Pulling: bittrex : VIB/ETH [241/279]
# Pulling: bittrex : VRC/BTC [242/279]
# Pulling: bittrex : VRM/BTC [243/279]
# Pulling: bittrex : VTC/BTC [244/279]
# Pulling: bittrex : VTR/BTC [245/279]
# Pulling: bittrex : WAVES/BTC [246/279]
# Pulling: bittrex : WAVES/ETH [247/279]
# Pulling: bittrex : WAX/BTC [248/279]
# Pulling: bittrex : WAX/ETH [249/279]
# Pulling: bittrex : WINGS/BTC [250/279]
# Pulling: bittrex : WINGS/ETH [251/279]
# Pulling: bittrex : XCP/BTC [252/279]
# Pulling: bittrex : XDN/BTC [253/279]
# Pulling: bittrex : XEL/BTC [254/279]
# Pulling: bittrex : XEM/BTC [255/279]
# Pulling: bittrex : XEM/ETH [256/279]
# Pulling: bittrex : XLM/BTC [257/279]
# Pulling: bittrex : XLM/ETH [258/279]
# Pulling: bittrex : XMG/BTC [259/279]
# Pulling: bittrex : XMR/BTC [260/279]
# Pulling: bittrex : XMR/ETH [261/279]
# Got an error ExchangeError ('bittrex returned an empty or unrecognized response: {"success":true,"message":"","result":null}',) , retrying in 30 seconds...
# Pulling: bittrex : XMR/ETH [261/279]
# Got an error ExchangeError ('bittrex returned an empty or unrecognized response: {"success":true,"message":"","result":null}',) , retrying in 30 seconds...
# Pulling: bittrex : XMR/ETH [261/279]
# Pulling: bittrex : XMR/USDT [262/279]
# Pulling: bittrex : XMY/BTC [263/279]
# Pulling: bittrex : XRP/BTC [264/279]
# Pulling: bittrex : XRP/ETH [265/279]
# Pulling: bittrex : XRP/USDT [266/279]
# Pulling: bittrex : XST/BTC [267/279]
# Pulling: bittrex : XVC/BTC [268/279]
# Got an error ExchangeError ('bittrex returned an empty or unrecognized response: {"success":true,"message":"","result":[]}',) , retrying in 30 seconds...
# Pulling: bittrex : XVC/BTC [268/279]
# Got an error ExchangeError ('bittrex returned an empty or unrecognized response: {"success":true,"message":"","result":[]}',) , retrying in 30 seconds...
# Pulling: bittrex : XVC/BTC [268/279]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 30 seconds...
# Pulling: bittrex : XVC-BTC [268/279]
# Got an error ExchangeError ('bittrex No market symbol XVC-BTC',) , retrying in 30 seconds...
# Pulling: bittrex : XVC-BTC [268/279]
# Got an error ExchangeError ('bittrex No market symbol XVC-BTC',) , retrying in 30 seconds...
# All attempts failed, skipping: XVC-BTC
# Pulling: bittrex : XVG/BTC [268/279]
# Pulling: bittrex : XVG/USDT [269/279]
# Got an error ExchangeError ('bittrex returned an empty or unrecognized response: {"success":true,"message":"","result":[]}',) , retrying in 30 seconds...
# Pulling: bittrex : XVG/USDT [269/279]
# Pulling: bittrex : XWC/BTC [270/279]
# Pulling: bittrex : XZC/BTC [271/279]
# Got an error RequestTimeout ("bittrex GET https://bittrex.com/api/v2.0/pub/market/GetTicks?tickInterval=hour&marketName=BTC-XZC HTTPSConnectionPool(host='bittrex.com', port=443): Read timed out. (read timeout=10)",) , retrying in 30 seconds...
# Pulling: bittrex : XZC/BTC [271/279]
# Pulling: bittrex : ZCL/BTC [272/279]
# Pulling: bittrex : ZEC/BTC [273/279]
# Pulling: bittrex : ZEC/ETH [274/279]
# Pulling: bittrex : ZEC/USDT [275/279]
# Pulling: bittrex : ZEN/BTC [276/279]
# Pulling: bittrex : ZRX/BTC [277/279]
# Got an error RequestTimeout ("bittrex GET https://bittrex.com/api/v2.0/pub/market/GetTicks?tickInterval=hour&marketName=BTC-ZRX HTTPSConnectionPool(host='bittrex.com', port=443): Read timed out. (read timeout=10)",) , retrying in 30 seconds...
# Pulling: bittrex : ZRX/BTC [277/279]
# Pulling: bittrex : ZRX/ETH [278/279]
# Unable to obtain: ['XVC-BTC']
# Pulling: binance : ADA/BNB [1/315]
# Pulling: binance : ADA/BTC [2/315]
# Pulling: binance : ADA/ETH [3/315]
# Pulling: binance : ADA/USDT [4/315]
# Pulling: binance : ADX/BNB [5/315]
# Pulling: binance : ADX/BTC [6/315]
# Pulling: binance : ADX/ETH [7/315]
# Pulling: binance : AE/BNB [8/315]
# Pulling: binance : AE/BTC [9/315]
# Pulling: binance : AE/ETH [10/315]
# Pulling: binance : AION/BNB [11/315]
# Pulling: binance : AION/BTC [12/315]
# Pulling: binance : AION/ETH [13/315]
# Pulling: binance : AMB/BNB [14/315]
# Pulling: binance : AMB/BTC [15/315]
# Pulling: binance : AMB/ETH [16/315]
# Pulling: binance : APPC/BNB [17/315]
# Pulling: binance : APPC/BTC [18/315]
# Pulling: binance : APPC/ETH [19/315]
# Pulling: binance : ARK/BTC [20/315]
# Pulling: binance : ARK/ETH [21/315]
# Pulling: binance : ARN/BTC [22/315]
# Pulling: binance : ARN/ETH [23/315]
# Pulling: binance : AST/BTC [24/315]
# Pulling: binance : AST/ETH [25/315]
# Pulling: binance : BAT/BNB [26/315]
# Pulling: binance : BAT/BTC [27/315]
# Pulling: binance : BAT/ETH [28/315]
# Pulling: binance : BCD/BTC [29/315]
# Pulling: binance : BCD/ETH [30/315]
# Pulling: binance : BCH/BNB [31/315]
# Pulling: binance : BCH/BTC [32/315]
# Pulling: binance : BCH/ETH [33/315]
# Pulling: binance : BCH/USDT [34/315]
# Pulling: binance : BCN/BNB [35/315]
# Pulling: binance : BCN/BTC [36/315]
# Pulling: binance : BCN/ETH [37/315]
# Pulling: binance : BCPT/BNB [38/315]
# Pulling: binance : BCPT/BTC [39/315]
# Pulling: binance : BCPT/ETH [40/315]
# Pulling: binance : BLZ/BNB [41/315]
# Pulling: binance : BLZ/BTC [42/315]
# Pulling: binance : BLZ/ETH [43/315]
# Pulling: binance : BNB/BTC [44/315]
# Pulling: binance : BNB/ETH [45/315]
# Pulling: binance : BNB/USDT [46/315]
# Pulling: binance : BNT/BTC [47/315]
# Pulling: binance : BNT/ETH [48/315]
# Pulling: binance : BQX/BTC [49/315]
# Pulling: binance : BQX/ETH [50/315]
# Pulling: binance : BRD/BNB [51/315]
# Pulling: binance : BRD/BTC [52/315]
# Pulling: binance : BRD/ETH [53/315]
# Pulling: binance : BTC/USDT [54/315]
# Pulling: binance : BTG/BTC [55/315]
# Pulling: binance : BTG/ETH [56/315]
# Pulling: binance : BTS/BNB [57/315]
# Pulling: binance : BTS/BTC [58/315]
# Pulling: binance : BTS/ETH [59/315]
# Pulling: binance : CDT/BTC [60/315]
# Pulling: binance : CDT/ETH [61/315]
# Pulling: binance : CHAT/BTC [62/315]
# Pulling: binance : CHAT/ETH [63/315]
# Pulling: binance : CLOAK/BTC [64/315]
# Pulling: binance : CLOAK/ETH [65/315]
# Pulling: binance : CMT/BNB [66/315]
# Pulling: binance : CMT/BTC [67/315]
# Pulling: binance : CMT/ETH [68/315]
# Pulling: binance : CND/BNB [69/315]
# Pulling: binance : CND/BTC [70/315]
# Pulling: binance : CND/ETH [71/315]
# Pulling: binance : DASH/BTC [72/315]
# Pulling: binance : DASH/ETH [73/315]
# Pulling: binance : DGD/BTC [74/315]
# Pulling: binance : DGD/ETH [75/315]
# Pulling: binance : DLT/BNB [76/315]
# Pulling: binance : DLT/BTC [77/315]
# Pulling: binance : DLT/ETH [78/315]
# Pulling: binance : DNT/BTC [79/315]
# Pulling: binance : DNT/ETH [80/315]
# Pulling: binance : EDO/BTC [81/315]
# Pulling: binance : EDO/ETH [82/315]
# Pulling: binance : ELF/BTC [83/315]
# Pulling: binance : ELF/ETH [84/315]
# Pulling: binance : ENG/BTC [85/315]
# Pulling: binance : ENG/ETH [86/315]
# Pulling: binance : ENJ/BTC [87/315]
# Pulling: binance : ENJ/ETH [88/315]
# Pulling: binance : EOS/BTC [89/315]
# Pulling: binance : EOS/ETH [90/315]
# Pulling: binance : ETC/BTC [91/315]
# Pulling: binance : ETC/ETH [92/315]
# Pulling: binance : ETH/BTC [93/315]
# Pulling: binance : ETH/USDT [94/315]
# Pulling: binance : EVX/BTC [95/315]
# Pulling: binance : EVX/ETH [96/315]
# Pulling: binance : FUEL/BTC [97/315]
# Pulling: binance : FUEL/ETH [98/315]
# Pulling: binance : FUN/BTC [99/315]
# Pulling: binance : FUN/ETH [100/315]
# Pulling: binance : GAS/BTC [101/315]
# Pulling: binance : GNT/BNB [102/315]
# Pulling: binance : GNT/BTC [103/315]
# Pulling: binance : GNT/ETH [104/315]
# Pulling: binance : GRS/BTC [105/315]
# Pulling: binance : GRS/ETH [106/315]
# Pulling: binance : GTO/BNB [107/315]
# Pulling: binance : GTO/BTC [108/315]
# Pulling: binance : GTO/ETH [109/315]
# Pulling: binance : GVT/BTC [110/315]
# Pulling: binance : GVT/ETH [111/315]
# Pulling: binance : GXS/BTC [112/315]
# Pulling: binance : GXS/ETH [113/315]
# Pulling: binance : HSR/BTC [114/315]
# Pulling: binance : HSR/ETH [115/315]
# Pulling: binance : ICN/BTC [116/315]
# Pulling: binance : ICN/ETH [117/315]
# Pulling: binance : ICX/BNB [118/315]
# Pulling: binance : ICX/BTC [119/315]
# Pulling: binance : ICX/ETH [120/315]
# Pulling: binance : INS/BTC [121/315]
# Pulling: binance : INS/ETH [122/315]
# Pulling: binance : IOST/BTC [123/315]
# Pulling: binance : IOST/ETH [124/315]
# Pulling: binance : IOTA/BNB [125/315]
# Pulling: binance : IOTA/BTC [126/315]
# Pulling: binance : IOTA/ETH [127/315]
# Pulling: binance : KMD/BTC [128/315]
# Pulling: binance : KMD/ETH [129/315]
# Pulling: binance : KNC/BTC [130/315]
# Pulling: binance : KNC/ETH [131/315]
# Pulling: binance : LEND/BTC [132/315]
# Pulling: binance : LEND/ETH [133/315]
# Pulling: binance : LINK/BTC [134/315]
# Pulling: binance : LINK/ETH [135/315]
# Pulling: binance : LOOM/BNB [136/315]
# Pulling: binance : LOOM/BTC [137/315]
# Pulling: binance : LOOM/ETH [138/315]
# Pulling: binance : LRC/BTC [139/315]
# Pulling: binance : LRC/ETH [140/315]
# Pulling: binance : LSK/BNB [141/315]
# Pulling: binance : LSK/BTC [142/315]
# Pulling: binance : LSK/ETH [143/315]
# Pulling: binance : LTC/BNB [144/315]
# Pulling: binance : LTC/BTC [145/315]
# Pulling: binance : LTC/ETH [146/315]
# Pulling: binance : LTC/USDT [147/315]
# Pulling: binance : LUN/BTC [148/315]
# Pulling: binance : LUN/ETH [149/315]
# Pulling: binance : MANA/BTC [150/315]
# Pulling: binance : MANA/ETH [151/315]
# Pulling: binance : MCO/BNB [152/315]
# Pulling: binance : MCO/BTC [153/315]
# Pulling: binance : MCO/ETH [154/315]
# Pulling: binance : MDA/BTC [155/315]
# Pulling: binance : MDA/ETH [156/315]
# Pulling: binance : MOD/BTC [157/315]
# Pulling: binance : MOD/ETH [158/315]
# Pulling: binance : MTH/BTC [159/315]
# Pulling: binance : MTH/ETH [160/315]
# Pulling: binance : MTL/BTC [161/315]
# Pulling: binance : MTL/ETH [162/315]
# Pulling: binance : NAV/BNB [163/315]
# Pulling: binance : NAV/BTC [164/315]
# Pulling: binance : NAV/ETH [165/315]
# Pulling: binance : NCASH/BNB [166/315]
# Pulling: binance : NCASH/BTC [167/315]
# Pulling: binance : NCASH/ETH [168/315]
# Pulling: binance : NEBL/BNB [169/315]
# Pulling: binance : NEBL/BTC [170/315]
# Pulling: binance : NEBL/ETH [171/315]
# Pulling: binance : NEO/BNB [172/315]
# Pulling: binance : NEO/BTC [173/315]
# Pulling: binance : NEO/ETH [174/315]
# Pulling: binance : NEO/USDT [175/315]
# Pulling: binance : NULS/BNB [176/315]
# Pulling: binance : NULS/BTC [177/315]
# Pulling: binance : NULS/ETH [178/315]
# Pulling: binance : OAX/BTC [179/315]
# Pulling: binance : OAX/ETH [180/315]
# Pulling: binance : OMG/BTC [181/315]
# Pulling: binance : OMG/ETH [182/315]
# Pulling: binance : ONT/BNB [183/315]
# Pulling: binance : ONT/BTC [184/315]
# Pulling: binance : ONT/ETH [185/315]
# Pulling: binance : OST/BNB [186/315]
# Pulling: binance : OST/BTC [187/315]
# Pulling: binance : OST/ETH [188/315]
# Pulling: binance : PIVX/BNB [189/315]
# Pulling: binance : PIVX/BTC [190/315]
# Pulling: binance : PIVX/ETH [191/315]
# Pulling: binance : POA/BNB [192/315]
# Pulling: binance : POA/BTC [193/315]
# Pulling: binance : POA/ETH [194/315]
# Pulling: binance : POE/BTC [195/315]
# Pulling: binance : POE/ETH [196/315]
# Pulling: binance : POWR/BNB [197/315]
# Pulling: binance : POWR/BTC [198/315]
# Pulling: binance : POWR/ETH [199/315]
# Pulling: binance : PPT/BTC [200/315]
# Pulling: binance : PPT/ETH [201/315]
# Pulling: binance : QLC/BNB [202/315]
# Pulling: binance : QLC/BTC [203/315]
# Pulling: binance : QLC/ETH [204/315]
# Pulling: binance : QSP/BNB [205/315]
# Pulling: binance : QSP/BTC [206/315]
# Pulling: binance : QSP/ETH [207/315]
# Pulling: binance : QTUM/BNB [208/315]
# Pulling: binance : QTUM/BTC [209/315]
# Pulling: binance : QTUM/ETH [210/315]
# Pulling: binance : QTUM/USDT [211/315]
# Pulling: binance : RCN/BNB [212/315]
# Pulling: binance : RCN/BTC [213/315]
# Pulling: binance : RCN/ETH [214/315]
# Pulling: binance : RDN/BNB [215/315]
# Pulling: binance : RDN/BTC [216/315]
# Pulling: binance : RDN/ETH [217/315]
# Pulling: binance : REP/BNB [218/315]
# Pulling: binance : REP/BTC [219/315]
# Pulling: binance : REP/ETH [220/315]
# Pulling: binance : REQ/BTC [221/315]
# Pulling: binance : REQ/ETH [222/315]
# Pulling: binance : RLC/BNB [223/315]
# Pulling: binance : RLC/BTC [224/315]
# Pulling: binance : RLC/ETH [225/315]
# Pulling: binance : RPX/BNB [226/315]
# Pulling: binance : RPX/BTC [227/315]
# Pulling: binance : RPX/ETH [228/315]
# Pulling: binance : SALT/BTC [229/315]
# Pulling: binance : SALT/ETH [230/315]
# Pulling: binance : SNGLS/BTC [231/315]
# Pulling: binance : SNGLS/ETH [232/315]
# Pulling: binance : SNM/BTC [233/315]
# Pulling: binance : SNM/ETH [234/315]
# Pulling: binance : SNT/BTC [235/315]
# Pulling: binance : SNT/ETH [236/315]
# Pulling: binance : STEEM/BNB [237/315]
# Pulling: binance : STEEM/BTC [238/315]
# Pulling: binance : STEEM/ETH [239/315]
# Pulling: binance : STORJ/BTC [240/315]
# Pulling: binance : STORJ/ETH [241/315]
# Pulling: binance : STORM/BNB [242/315]
# Pulling: binance : STORM/BTC [243/315]
# Pulling: binance : STORM/ETH [244/315]
# Pulling: binance : STRAT/BTC [245/315]
# Pulling: binance : STRAT/ETH [246/315]
# Pulling: binance : SUB/BTC [247/315]
# Pulling: binance : SUB/ETH [248/315]
# Pulling: binance : SYS/BNB [249/315]
# Pulling: binance : SYS/BTC [250/315]
# Pulling: binance : SYS/ETH [251/315]
# Pulling: binance : TNB/BTC [252/315]
# Pulling: binance : TNB/ETH [253/315]
# Pulling: binance : TNT/BTC [254/315]
# Pulling: binance : TNT/ETH [255/315]
# Pulling: binance : TRIG/BNB [256/315]
# Pulling: binance : TRIG/BTC [257/315]
# Pulling: binance : TRIG/ETH [258/315]
# Pulling: binance : TRX/BTC [259/315]
# Pulling: binance : TRX/ETH [260/315]
# Pulling: binance : VEN/BNB [261/315]
# Pulling: binance : VEN/BTC [262/315]
# Pulling: binance : VEN/ETH [263/315]
# Pulling: binance : VIA/BNB [264/315]
# Pulling: binance : VIA/BTC [265/315]
# Pulling: binance : VIA/ETH [266/315]
# Pulling: binance : VIB/BTC [267/315]
# Pulling: binance : VIB/ETH [268/315]
# Pulling: binance : VIBE/BTC [269/315]
# Pulling: binance : VIBE/ETH [270/315]
# Pulling: binance : WABI/BNB [271/315]
# Pulling: binance : WABI/BTC [272/315]
# Pulling: binance : WABI/ETH [273/315]
# Pulling: binance : WAN/BNB [274/315]
# Pulling: binance : WAN/BTC [275/315]
# Pulling: binance : WAN/ETH [276/315]
# Pulling: binance : WAVES/BNB [277/315]
# Pulling: binance : WAVES/BTC [278/315]
# Pulling: binance : WAVES/ETH [279/315]
# Pulling: binance : WINGS/BTC [280/315]
# Pulling: binance : WINGS/ETH [281/315]
# Pulling: binance : WPR/BTC [282/315]
# Pulling: binance : WPR/ETH [283/315]
# Pulling: binance : WTC/BNB [284/315]
# Pulling: binance : WTC/BTC [285/315]
# Pulling: binance : WTC/ETH [286/315]
# Pulling: binance : XEM/BNB [287/315]
# Pulling: binance : XEM/BTC [288/315]
# Pulling: binance : XEM/ETH [289/315]
# Pulling: binance : XLM/BNB [290/315]
# Pulling: binance : XLM/BTC [291/315]
# Pulling: binance : XLM/ETH [292/315]
# Pulling: binance : XMR/BTC [293/315]
# Pulling: binance : XMR/ETH [294/315]
# Pulling: binance : XRB/BNB [295/315]
# Pulling: binance : XRB/BTC [296/315]
# Pulling: binance : XRB/ETH [297/315]
# Pulling: binance : XRP/BTC [298/315]
# Pulling: binance : XRP/ETH [299/315]
# Pulling: binance : XRP/USDT [300/315]
# Pulling: binance : XVG/BTC [301/315]
# Pulling: binance : XVG/ETH [302/315]
# Pulling: binance : XZC/BNB [303/315]
# Pulling: binance : XZC/BTC [304/315]
# Pulling: binance : XZC/ETH [305/315]
# Pulling: binance : YOYOW/BNB [306/315]
# Pulling: binance : YOYOW/BTC [307/315]
# Pulling: binance : YOYOW/ETH [308/315]
# Pulling: binance : ZEC/BTC [309/315]
# Pulling: binance : ZEC/ETH [310/315]
# Pulling: binance : ZIL/BNB [311/315]
# Pulling: binance : ZIL/BTC [312/315]
# Pulling: binance : ZIL/ETH [313/315]
# Pulling: binance : ZRX/BTC [314/315]
# Pulling: binance : ZRX/ETH [315/315]
# Pulling: kraken : BCH/BTC [1/68]
# Pulling: kraken : BCH/EUR [2/68]
# Pulling: kraken : BCH/USD [3/68]
# Pulling: kraken : BTC/CAD [4/68]
# Pulling: kraken : BTC/EUR [5/68]
# Pulling: kraken : BTC/GBP [6/68]
# Pulling: kraken : BTC/JPY [7/68]
# Pulling: kraken : BTC/USD [8/68]
# Pulling: kraken : DASH/BTC [9/68]
# Pulling: kraken : DASH/EUR [10/68]
# Pulling: kraken : DASH/USD [11/68]
# Got an error ExchangeNotAvailable ('kraken {"error":["EService:Unavailable"]}',) , retrying in 30 seconds...
# Pulling: kraken : DASH/USD [11/68]
# Pulling: kraken : EOS/BTC [12/68]
# Pulling: kraken : EOS/ETH [13/68]
# Pulling: kraken : EOS/EUR [14/68]
# Pulling: kraken : EOS/USD [15/68]
# Pulling: kraken : ETC/BTC [16/68]
# Pulling: kraken : ETC/ETH [17/68]
# Pulling: kraken : ETC/EUR [18/68]
# Pulling: kraken : ETC/USD [19/68]
# Pulling: kraken : ETH/BTC [20/68]
# Pulling: kraken : ETH/CAD [21/68]
# Pulling: kraken : ETH/EUR [22/68]
# Pulling: kraken : ETH/GBP [23/68]
# Pulling: kraken : ETH/JPY [24/68]
# Pulling: kraken : ETH/USD [25/68]
# Pulling: kraken : ETHCAD.d [26/68]
# Got an error ExchangeError ('kraken {"error":["EQuery:Unknown asset pair"]}',) , retrying in 30 seconds...
# Pulling: kraken : ETHCAD.d [26/68]
# Got an error ExchangeError ('kraken {"error":["EQuery:Unknown asset pair"]}',) , retrying in 30 seconds...
# Pulling: kraken : ETHCAD.d [26/68]
# Got an error ExchangeError ('kraken {"error":["EQuery:Unknown asset pair"]}',) , retrying in 30 seconds...
# Pulling: kraken : ETHCAD.d [26/68]
# Got an error ExchangeError ('kraken {"error":["EQuery:Unknown asset pair"]}',) , retrying in 30 seconds...
# Pulling: kraken : ETHCAD.d [26/68]
# Got an error ExchangeError ('kraken {"error":["EQuery:Unknown asset pair"]}',) , retrying in 30 seconds...
# All attempts failed, skipping: ETHCAD.d
# Pulling: kraken : ETHEUR.d [26/68]
# Got an error ExchangeError ('kraken {"error":["EQuery:Unknown asset pair"]}',) , retrying in 30 seconds...
# Pulling: kraken : ETHEUR.d [26/68]
# Got an error ExchangeError ('kraken {"error":["EQuery:Unknown asset pair"]}',) , retrying in 30 seconds...
# Pulling: kraken : ETHEUR.d [26/68]
# Got an error ExchangeError ('kraken {"error":["EQuery:Unknown asset pair"]}',) , retrying in 30 seconds...
# Pulling: kraken : ETHEUR.d [26/68]
# Got an error ExchangeError ('kraken {"error":["EQuery:Unknown asset pair"]}',) , retrying in 30 seconds...
# Pulling: kraken : ETHEUR.d [26/68]
# Got an error ExchangeError ('kraken {"error":["EQuery:Unknown asset pair"]}',) , retrying in 30 seconds...
# All attempts failed, skipping: ETHEUR.d
# Pulling: kraken : ETHGBP.d [26/68]
# Got an error ExchangeError ('kraken {"error":["EQuery:Unknown asset pair"]}',) , retrying in 30 seconds...
# Pulling: kraken : ETHGBP.d [26/68]
# Got an error ExchangeError ('kraken {"error":["EQuery:Unknown asset pair"]}',) , retrying in 30 seconds...
# Pulling: kraken : ETHGBP.d [26/68]
# Got an error ExchangeError ('kraken {"error":["EQuery:Unknown asset pair"]}',) , retrying in 30 seconds...
# Pulling: kraken : ETHGBP.d [26/68]
# Got an error ExchangeError ('kraken {"error":["EQuery:Unknown asset pair"]}',) , retrying in 30 seconds...
# Pulling: kraken : ETHGBP.d [26/68]
# Got an error ExchangeError ('kraken {"error":["EQuery:Unknown asset pair"]}',) , retrying in 30 seconds...
# All attempts failed, skipping: ETHGBP.d
# Pulling: kraken : ETHJPY.d [26/68]
# Got an error ExchangeError ('kraken {"error":["EQuery:Unknown asset pair"]}',) , retrying in 30 seconds...
# Pulling: kraken : ETHJPY.d [26/68]
# Got an error ExchangeError ('kraken {"error":["EQuery:Unknown asset pair"]}',) , retrying in 30 seconds...
# Pulling: kraken : ETHJPY.d [26/68]
# Got an error ExchangeError ('kraken {"error":["EQuery:Unknown asset pair"]}',) , retrying in 30 seconds...
# Pulling: kraken : ETHJPY.d [26/68]
# Got an error ExchangeError ('kraken {"error":["EQuery:Unknown asset pair"]}',) , retrying in 30 seconds...
# Pulling: kraken : ETHJPY.d [26/68]
# Got an error ExchangeError ('kraken {"error":["EQuery:Unknown asset pair"]}',) , retrying in 30 seconds...
# All attempts failed, skipping: ETHJPY.d
# Pulling: kraken : ETHUSD.d [26/68]
# Got an error ExchangeError ('kraken {"error":["EQuery:Unknown asset pair"]}',) , retrying in 30 seconds...
# Pulling: kraken : ETHUSD.d [26/68]
# Got an error ExchangeError ('kraken {"error":["EQuery:Unknown asset pair"]}',) , retrying in 30 seconds...
# Pulling: kraken : ETHUSD.d [26/68]
# Got an error ExchangeError ('kraken {"error":["EQuery:Unknown asset pair"]}',) , retrying in 30 seconds...
# Pulling: kraken : ETHUSD.d [26/68]
# Got an error ExchangeError ('kraken {"error":["EQuery:Unknown asset pair"]}',) , retrying in 30 seconds...
# Pulling: kraken : ETHUSD.d [26/68]
# Got an error ExchangeError ('kraken {"error":["EQuery:Unknown asset pair"]}',) , retrying in 30 seconds...
# All attempts failed, skipping: ETHUSD.d
# Pulling: kraken : ETHXBT.d [26/68]
# Got an error ExchangeError ('kraken {"error":["EQuery:Unknown asset pair"]}',) , retrying in 30 seconds...
# Pulling: kraken : ETHXBT.d [26/68]
# Got an error ExchangeError ('kraken {"error":["EQuery:Unknown asset pair"]}',) , retrying in 30 seconds...
# Pulling: kraken : ETHXBT.d [26/68]
# Got an error RequestTimeout ("kraken GET https://api.kraken.com/0/public/OHLC?pair=XETHXXBT.d&interval=60&since=1524182400 HTTPSConnectionPool(host='api.kraken.com', port=443): Read timed out. (read timeout=10)",) , retrying in 30 seconds...
# Pulling: kraken : ETHXBT.d [26/68]
# Got an error ExchangeError ('kraken {"error":["EQuery:Unknown asset pair"]}',) , retrying in 30 seconds...
# Pulling: kraken : ETHXBT.d [26/68]
# Got an error ExchangeError ('kraken {"error":["EQuery:Unknown asset pair"]}',) , retrying in 30 seconds...
# All attempts failed, skipping: ETHXBT.d
# Pulling: kraken : GNO/BTC [26/68]
# Got an error RequestTimeout ("kraken GET https://api.kraken.com/0/public/OHLC?pair=GNOXBT&interval=60&since=1524182400 HTTPSConnectionPool(host='api.kraken.com', port=443): Read timed out. (read timeout=10)",) , retrying in 30 seconds...
# Pulling: kraken : GNO/BTC [26/68]
# Pulling: kraken : GNO/ETH [27/68]
# Pulling: kraken : GNO/EUR [28/68]
# Pulling: kraken : GNO/USD [29/68]
# Pulling: kraken : ICN/BTC [30/68]
# Pulling: kraken : ICN/ETH [31/68]
# Pulling: kraken : LTC/BTC [32/68]
# Got an error RequestTimeout ("kraken GET https://api.kraken.com/0/public/OHLC?pair=XLTCXXBT&interval=60&since=1524182400 HTTPSConnectionPool(host='api.kraken.com', port=443): Read timed out. (read timeout=10)",) , retrying in 30 seconds...
# Pulling: kraken : LTC/BTC [32/68]
# Pulling: kraken : LTC/EUR [33/68]
# Pulling: kraken : LTC/USD [34/68]
# Pulling: kraken : MLN/BTC [35/68]
# Pulling: kraken : MLN/ETH [36/68]
# Pulling: kraken : REP/BTC [37/68]
# Pulling: kraken : REP/ETH [38/68]
# Pulling: kraken : REP/EUR [39/68]
# Got an error RequestTimeout ("kraken GET https://api.kraken.com/0/public/OHLC?pair=XREPZEUR&interval=60&since=1524182400 HTTPSConnectionPool(host='api.kraken.com', port=443): Read timed out. (read timeout=10)",) , retrying in 30 seconds...
# Pulling: kraken : REP/EUR [39/68]
# Pulling: kraken : REP/USD [40/68]
# Pulling: kraken : USDT/USD [41/68]
# Pulling: kraken : XBTCAD.d [42/68]
# Got an error ExchangeError ('kraken {"error":["EQuery:Unknown asset pair"]}',) , retrying in 30 seconds...
# Pulling: kraken : XBTCAD.d [42/68]
# Got an error ExchangeError ('kraken {"error":["EQuery:Unknown asset pair"]}',) , retrying in 30 seconds...
# Pulling: kraken : XBTCAD.d [42/68]
# Got an error ExchangeError ('kraken {"error":["EQuery:Unknown asset pair"]}',) , retrying in 30 seconds...
# Pulling: kraken : XBTCAD.d [42/68]
# Got an error ExchangeError ('kraken {"error":["EQuery:Unknown asset pair"]}',) , retrying in 30 seconds...
# Pulling: kraken : XBTCAD.d [42/68]
# Got an error ExchangeError ('kraken {"error":["EQuery:Unknown asset pair"]}',) , retrying in 30 seconds...
# All attempts failed, skipping: XBTCAD.d
# Pulling: kraken : XBTEUR.d [42/68]
# Got an error ExchangeError ('kraken {"error":["EQuery:Unknown asset pair"]}',) , retrying in 30 seconds...
# Pulling: kraken : XBTEUR.d [42/68]
# Got an error ExchangeError ('kraken {"error":["EQuery:Unknown asset pair"]}',) , retrying in 30 seconds...
# Pulling: kraken : XBTEUR.d [42/68]
# Got an error ExchangeError ('kraken {"error":["EQuery:Unknown asset pair"]}',) , retrying in 30 seconds...
# Pulling: kraken : XBTEUR.d [42/68]
# Got an error ExchangeError ('kraken {"error":["EQuery:Unknown asset pair"]}',) , retrying in 30 seconds...
# Pulling: kraken : XBTEUR.d [42/68]
# Got an error ExchangeError ('kraken {"error":["EQuery:Unknown asset pair"]}',) , retrying in 30 seconds...
# All attempts failed, skipping: XBTEUR.d
# Pulling: kraken : XBTGBP.d [42/68]
# Got an error RequestTimeout ("kraken GET https://api.kraken.com/0/public/OHLC?pair=XXBTZGBP.d&interval=60&since=1524182400 HTTPSConnectionPool(host='api.kraken.com', port=443): Read timed out. (read timeout=10)",) , retrying in 30 seconds...
# Pulling: kraken : XBTGBP.d [42/68]
# Got an error ExchangeError ('kraken {"error":["EQuery:Unknown asset pair"]}',) , retrying in 30 seconds...
# Pulling: kraken : XBTGBP.d [42/68]
# Got an error ExchangeError ('kraken {"error":["EQuery:Unknown asset pair"]}',) , retrying in 30 seconds...
# Pulling: kraken : XBTGBP.d [42/68]
# Got an error ExchangeError ('kraken {"error":["EQuery:Unknown asset pair"]}',) , retrying in 30 seconds...
# Pulling: kraken : XBTGBP.d [42/68]
# Got an error ExchangeError ('kraken {"error":["EQuery:Unknown asset pair"]}',) , retrying in 30 seconds...
# All attempts failed, skipping: XBTGBP.d
# Pulling: kraken : XBTJPY.d [42/68]
# Got an error ExchangeError ('kraken {"error":["EQuery:Unknown asset pair"]}',) , retrying in 30 seconds...
# Pulling: kraken : XBTJPY.d [42/68]
# Got an error ExchangeError ('kraken {"error":["EQuery:Unknown asset pair"]}',) , retrying in 30 seconds...
# Pulling: kraken : XBTJPY.d [42/68]
# Got an error ExchangeError ('kraken {"error":["EQuery:Unknown asset pair"]}',) , retrying in 30 seconds...
# Pulling: kraken : XBTJPY.d [42/68]
# Got an error ExchangeError ('kraken {"error":["EQuery:Unknown asset pair"]}',) , retrying in 30 seconds...
# Pulling: kraken : XBTJPY.d [42/68]
# Got an error ExchangeError ('kraken {"error":["EQuery:Unknown asset pair"]}',) , retrying in 30 seconds...
# All attempts failed, skipping: XBTJPY.d
# Pulling: kraken : XBTUSD.d [42/68]
# Got an error ExchangeError ('kraken {"error":["EQuery:Unknown asset pair"]}',) , retrying in 30 seconds...
# Pulling: kraken : XBTUSD.d [42/68]
# Got an error ExchangeError ('kraken {"error":["EQuery:Unknown asset pair"]}',) , retrying in 30 seconds...
# Pulling: kraken : XBTUSD.d [42/68]
# Got an error RequestTimeout ("kraken GET https://api.kraken.com/0/public/OHLC?pair=XXBTZUSD.d&interval=60&since=1524182400 HTTPSConnectionPool(host='api.kraken.com', port=443): Read timed out. (read timeout=10)",) , retrying in 30 seconds...
# Pulling: kraken : XBTUSD.d [42/68]
# Got an error ExchangeError ('kraken {"error":["EQuery:Unknown asset pair"]}',) , retrying in 30 seconds...
# Pulling: kraken : XBTUSD.d [42/68]
# Got an error ExchangeError ('kraken {"error":["EQuery:Unknown asset pair"]}',) , retrying in 30 seconds...
# All attempts failed, skipping: XBTUSD.d
# Pulling: kraken : XDG/BTC [42/68]
# Pulling: kraken : XLM/BTC [43/68]
# Got an error RequestTimeout ("kraken GET https://api.kraken.com/0/public/OHLC?pair=XXLMXXBT&interval=60&since=1524182400 HTTPSConnectionPool(host='api.kraken.com', port=443): Read timed out. (read timeout=10)",) , retrying in 30 seconds...
# Pulling: kraken : XLM/BTC [43/68]
# Pulling: kraken : XLM/EUR [44/68]
# Pulling: kraken : XLM/USD [45/68]
# Pulling: kraken : XMR/BTC [46/68]
# Got an error ExchangeNotAvailable ('kraken https://api.kraken.com/0/public/OHLC?pair=XXMRXXBT&interval=60&since=1524182400 GET 520 Server Error: Origin Error for url: https://api.kraken.com/0/public/OHLC?pair=XXMRXXBT&interval=60&since=1524182400 <!DOCTYPE html>\n<!--[if lt IE 7]> <html class="no-js ie6 oldie" lang="en-US"> <![endif]-->\n<!--[if IE 7]>    <html class="no-js ie7 oldie" lang="en-US"> <![endif]-->\n<!--[if IE 8]>    <html class="no-js ie8 oldie" lang="en-US"> <![endif]-->\n<!--[if gt IE 8]><!--> <html class="no-js" lang="en-US"> <!--<![endif]-->\n<head>\n<title>api.kraken.com | 520: Web server is returning an unknown error</title>\n<meta charset="UTF-8" />\n<meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />\n<meta http-equiv="X-UA-Compatible" content="IE=Edge,chrome=1" />\n<meta name="robots" content="noindex, nofollow" />\n<meta name="viewport" content="width=device-width,initial-scale=1,maximum-scale=1" />\n<link rel="stylesheet" id="cf_styles-css" href="/cdn-cgi/styles/cf.errors.css" type="text/css" media="screen,projection" />\n<!--[if lt IE 9]><link rel="stylesheet" id=\'cf_styles-ie-css\' href="/cdn-cgi/styles/cf.errors.ie.css" type="text/css" media="screen,projection" /><![endif]-->\n<style type="text/css">body{margin:0;padding:0}</style>\n</head>\n<body>\n<div id="cf-wrapper">\n<div id="cf-error-details" class="cf-error-details-wrapper">\n<div class="cf-wrapper cf-error-overview">\n<h1>\n<span class="cf-error-type">Error</span>\n<span class="cf-error-code">520</span>\n<small class="heading-ray-id">Ray ID: 41bcdac59f8f9c1d &bull; 2018-05-16 09:35:37 UTC</small>\n</h1>\n<h2 class="cf-subheadline">Web server is returning an unknown error</h2>\n</div>\n<div class="cf-section cf-highlight cf-status-display">\n<div class="cf-wrapper">\n<div class="cf-columns cols-3">\n<div id="cf-browser-status" class="cf-column cf-status-item cf-browser-status ">\n<div class="cf-icon-error-container">\n<i class="cf-icon cf-icon-browser"></i>\n<i class="cf-icon-status cf-icon-ok"></i>\n</div>\n<span class="cf-status-desc">You</span>\n<h3 class="cf-status-name">Browser</h3>\n<span class="cf-status-label">Working</span>\n</div>\n<div id="cf-cloudflare-status" class="cf-column cf-status-item cf-cloudflare-status ">\n<div class="cf-icon-error-container">\n<i class="cf-icon cf-icon-cloud"></i>\n<i class="cf-icon-status cf-icon-ok"></i>\n</div>\n<span class="cf-status-desc">Amsterdam</span>\n<h3 class="cf-status-name">Cloudflare</h3>\n<span class="cf-status-label">Working</span>\n</div>\n<div id="cf-host-status" class="cf-column cf-status-item cf-host-status cf-error-source">\n<div class="cf-icon-error-container">\n<i class="cf-icon cf-icon-server"></i>\n<i class="cf-icon-status cf-icon-error"></i>\n</div>\n<span class="cf-status-desc">api.kraken.com</span>\n<h3 class="cf-status-name">Host</h3>\n<span class="cf-status-label">Error</span>\n</div>\n</div>\n</div>\n</div>\n<div class="cf-section cf-wrapper">\n<div class="cf-columns two">\n<div class="cf-column">\n<h2>What happened?</h2>\n<p>There is an unknown connection issue between Cloudflare and the origin web server. As a result, the web page can not be displayed.</p>\n</div>\n<div class="cf-column">\n<h2>What can I do?</h2>\n<h5>If you are a visitor of this website:</h5>\n<p>Please try again in a few minutes.</p>\n<h5>If you are the owner of this website:</h5>\n<p><span>There is an issue between Cloudflare\'s cache and your origin web server. Cloudflare monitors for these errors and automatically investigates the cause. To help support the investigation, you can pull the corresponding error log from your web server and submit it our support team. Please include the Ray ID (which is at the bottom of this error page).</span> <a href="https://support.cloudflare.com/hc/en-us/articles/200171936-Error-520">Additional troubleshooting resources</a>.</p>\n</div>\n</div>\n</div>\n<div class="cf-error-footer cf-wrapper">\n<p>\n<span class="cf-footer-item">Cloudflare Ray ID ...
# Pulling: kraken : XMR/BTC [46/68]
# Got an error RequestTimeout ("kraken GET https://api.kraken.com/0/public/OHLC?pair=XXMRXXBT&interval=60&since=1524182400 HTTPSConnectionPool(host='api.kraken.com', port=443): Read timed out. (read timeout=10)",) , retrying in 30 seconds...
# Pulling: kraken : XMR/BTC [46/68]
# Pulling: kraken : XMR/EUR [47/68]
# Pulling: kraken : XMR/USD [48/68]
# Pulling: kraken : XRP/BTC [49/68]
# Got an error RequestTimeout ("kraken GET https://api.kraken.com/0/public/OHLC?pair=XXRPXXBT&interval=60&since=1524182400 HTTPSConnectionPool(host='api.kraken.com', port=443): Read timed out. (read timeout=10)",) , retrying in 30 seconds...
# Pulling: kraken : XRP/BTC [49/68]
# Pulling: kraken : XRP/CAD [50/68]
# Pulling: kraken : XRP/EUR [51/68]
# Got an error RequestTimeout ("kraken GET https://api.kraken.com/0/public/OHLC?pair=XXRPZEUR&interval=60&since=1524182400 HTTPSConnectionPool(host='api.kraken.com', port=443): Read timed out. (read timeout=10)",) , retrying in 30 seconds...
# Pulling: kraken : XRP/EUR [51/68]
# Pulling: kraken : XRP/JPY [52/68]
# Pulling: kraken : XRP/USD [53/68]
# Pulling: kraken : ZEC/BTC [54/68]
# Got an error RequestTimeout ("kraken GET https://api.kraken.com/0/public/OHLC?pair=XZECXXBT&interval=60&since=1524182400 HTTPSConnectionPool(host='api.kraken.com', port=443): Read timed out. (read timeout=10)",) , retrying in 30 seconds...
# Pulling: kraken : ZEC/BTC [54/68]
# Pulling: kraken : ZEC/EUR [55/68]
# Pulling: kraken : ZEC/JPY [56/68]
# Pulling: kraken : ZEC/USD [57/68]
# Unable to obtain: ['ETHCAD.d', 'ETHEUR.d', 'ETHGBP.d', 'ETHJPY.d', 'ETHUSD.d', 'ETHXBT.d', 'XBTCAD.d', 'XBTEUR.d', 'XBTGBP.d', 'XBTJPY.d', 'XBTUSD.d']
# Pulling: kucoin : ABT/BTC [1/319]
# Pulling: kucoin : ABT/ETH [2/319]
# Pulling: kucoin : ACAT/BTC [3/319]
# Pulling: kucoin : ACAT/ETH [4/319]
# Pulling: kucoin : ACT/BTC [5/319]
# Pulling: kucoin : ACT/ETH [6/319]
# Pulling: kucoin : ACT/USDT [7/319]
# Pulling: kucoin : ADB/BTC [8/319]
# Pulling: kucoin : ADB/ETH [9/319]
# Pulling: kucoin : AGI/BTC [10/319]
# Pulling: kucoin : AGI/ETH [11/319]
# Pulling: kucoin : AION/BTC [12/319]
# Pulling: kucoin : AION/ETH [13/319]
# Pulling: kucoin : AIX/BTC [14/319]
# Pulling: kucoin : AIX/ETH [15/319]
# Pulling: kucoin : AMB/BTC [16/319]
# Pulling: kucoin : AMB/ETH [17/319]
# Pulling: kucoin : APH/BTC [18/319]
# Pulling: kucoin : APH/ETH [19/319]
# Pulling: kucoin : APH/NEO [20/319]
# Pulling: kucoin : ARN/BTC [21/319]
# Pulling: kucoin : ARN/ETH [22/319]
# Pulling: kucoin : ARY/BTC [23/319]
# Pulling: kucoin : ARY/ETH [24/319]
# Pulling: kucoin : AXP/BTC [25/319]
# Pulling: kucoin : AXP/ETH [26/319]
# Pulling: kucoin : BCD/BTC [27/319]
# Pulling: kucoin : BCD/ETH [28/319]
# Pulling: kucoin : BCH/BTC [29/319]
# Pulling: kucoin : BCH/ETH [30/319]
# Pulling: kucoin : BCH/KCS [31/319]
# Pulling: kucoin : BCH/USDT [32/319]
# Pulling: kucoin : BCPT/BTC [33/319]
# Pulling: kucoin : BCPT/ETH [34/319]
# Pulling: kucoin : BHC/BTC [35/319]
# Got an error ExchangeNotAvailable ('kucoin https://api.kucoin.com/v1/open/chart/history?symbol=BHC-BTC&resolution=60&from=1524182400&to=1525910400 GET 404 Client Error:  for url: https://api.kucoin.com/v1/open/chart/history?symbol=BHC-BTC&resolution=60&from=1524182400&to=1525910400 ',) , retrying in 30 seconds...
# Pulling: kucoin : BHC/BTC [35/319]
# Got an error ExchangeNotAvailable ('kucoin https://api.kucoin.com/v1/open/chart/history?symbol=BHC-BTC&resolution=60&from=1524182400&to=1525910400 GET 404 Client Error:  for url: https://api.kucoin.com/v1/open/chart/history?symbol=BHC-BTC&resolution=60&from=1524182400&to=1525910400 ',) , retrying in 30 seconds...
# Pulling: kucoin : BHC/BTC [35/319]
# Got an error ExchangeNotAvailable ('kucoin https://api.kucoin.com/v1/open/chart/history?symbol=BHC-BTC&resolution=60&from=1524182400&to=1525910400 GET 404 Client Error:  for url: https://api.kucoin.com/v1/open/chart/history?symbol=BHC-BTC&resolution=60&from=1524182400&to=1525910400 ',) , retrying in 30 seconds...
# Pulling: kucoin : BHC/BTC [35/319]
# Got an error ExchangeNotAvailable ('kucoin https://api.kucoin.com/v1/open/chart/history?symbol=BHC-BTC&resolution=60&from=1524182400&to=1525910400 GET 404 Client Error:  for url: https://api.kucoin.com/v1/open/chart/history?symbol=BHC-BTC&resolution=60&from=1524182400&to=1525910400 ',) , retrying in 30 seconds...
# Pulling: kucoin : BHC/BTC [35/319]
# Got an error ExchangeError ('kucoin: unknown response: {"code":"ERROR","msg":"SYMBOL NOT FOUND","success":false,"timestamp":1526464033536}',) , retrying in 30 seconds...
# All attempts failed, skipping: BHC/BTC
# Pulling: kucoin : BNTY/BTC [35/319]
# Pulling: kucoin : BNTY/ETH [36/319]
# Pulling: kucoin : BOS/BTC [37/319]
# Pulling: kucoin : BOS/ETH [38/319]
# Pulling: kucoin : BPT/BTC [39/319]
# Pulling: kucoin : BPT/ETH [40/319]
# Pulling: kucoin : BRD/BTC [41/319]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 30 seconds...
# Pulling: kucoin : BRD-BTC [41/319]
# Got an error ExchangeError ('kucoin No market symbol BRD-BTC',) , retrying in 30 seconds...
# Pulling: kucoin : BRD-BTC [41/319]
# Got an error ExchangeError ('kucoin No market symbol BRD-BTC',) , retrying in 30 seconds...
# Pulling: kucoin : BRD-BTC [41/319]
# Got an error ExchangeError ('kucoin No market symbol BRD-BTC',) , retrying in 30 seconds...
# Pulling: kucoin : BRD-BTC [41/319]
# ...
# Pulling: kucoin : MAN-ETH [183/319]
# Got an error ExchangeError ('kucoin No market symbol MAN-ETH',) , retrying in 30 seconds...
# All attempts failed, skipping: MAN-ETH
# Pulling: kucoin : MANA/BTC [183/319]
# Pulling: kucoin : MANA/ETH [184/319]
# Pulling: kucoin : MOD/BTC [185/319]
# Pulling: kucoin : MOD/ETH [186/319]
# Pulling: kucoin : MTH/BTC [187/319]
# Pulling: kucoin : MTH/ETH [188/319]
# Pulling: kucoin : MTN/BTC [189/319]
# Pulling: kucoin : MTN/ETH [190/319]
# Pulling: kucoin : MWAT/BTC [191/319]
# Pulling: kucoin : MWAT/ETH [192/319]
# Pulling: kucoin : NEBL/BTC [193/319]
# Pulling: kucoin : NEBL/ETH [194/319]
# Pulling: kucoin : NEO/BTC [195/319]
# Pulling: kucoin : NEO/ETH [196/319]
# Pulling: kucoin : NEO/KCS [197/319]
# Pulling: kucoin : NEO/USDT [198/319]
# Pulling: kucoin : NULS/BTC [199/319]
# Pulling: kucoin : NULS/ETH [200/319]
# Pulling: kucoin : OCN/BTC [201/319]
# Got an error RequestTimeout ("kucoin GET https://api.kucoin.com/v1/open/chart/history?symbol=OCN-BTC&resolution=60&from=1524182400&to=1525910400 HTTPSConnectionPool(host='api.kucoin.com', port=443): Read timed out. (read timeout=10)",) , retrying in 30 seconds...
# Pulling: kucoin : OCN/BTC [201/319]
# Pulling: kucoin : OCN/ETH [202/319]
# Pulling: kucoin : OMG/BTC [203/319]
# Pulling: kucoin : OMG/ETH [204/319]
# Pulling: kucoin : ONION/BTC [205/319]
# Pulling: kucoin : ONION/ETH [206/319]
# Pulling: kucoin : ONT/BTC [207/319]
# Pulling: kucoin : ONT/ETH [208/319]
# Pulling: kucoin : ONT/NEO [209/319]
# Pulling: kucoin : PARETO/BTC [210/319]
# Pulling: kucoin : PARETO/ETH [211/319]
# Pulling: kucoin : PAY/BTC [212/319]
# Pulling: kucoin : PAY/ETH [213/319]
# Pulling: kucoin : PBL/BTC [214/319]
# Pulling: kucoin : PBL/ETH [215/319]
# Pulling: kucoin : PLAY/BTC [216/319]
# Pulling: kucoin : PLAY/ETH [217/319]
# Pulling: kucoin : POE/BTC [218/319]
# Pulling: kucoin : POE/ETH [219/319]
# Pulling: kucoin : POLL/BTC [220/319]
# Pulling: kucoin : POLL/ETH [221/319]
# Pulling: kucoin : POLY/BTC [222/319]
# Pulling: kucoin : POLY/ETH [223/319]
# Pulling: kucoin : POWR/BTC [224/319]
# Pulling: kucoin : POWR/ETH [225/319]
# Pulling: kucoin : PPT/BTC [226/319]
# Pulling: kucoin : PPT/ETH [227/319]
# Pulling: kucoin : PRL/BTC [228/319]
# Pulling: kucoin : PRL/ETH [229/319]
# Pulling: kucoin : PRL/NEO [230/319]
# Pulling: kucoin : PURA/BTC [231/319]
# Pulling: kucoin : PURA/ETH [232/319]
# Pulling: kucoin : QLC/BTC [233/319]
# Pulling: kucoin : QLC/ETH [234/319]
# Pulling: kucoin : QLC/NEO [235/319]
# Pulling: kucoin : QSP/BTC [236/319]
# Pulling: kucoin : QSP/ETH [237/319]
# Pulling: kucoin : QTUM/BTC [238/319]
# Pulling: kucoin : R/BTC [239/319]
# Pulling: kucoin : R/ETH [240/319]
# Pulling: kucoin : RDN/BTC [241/319]
# Pulling: kucoin : RDN/ETH [242/319]
# Pulling: kucoin : REQ/BTC [243/319]
# Pulling: kucoin : REQ/ETH [244/319]
# Pulling: kucoin : RHOC/BTC [245/319]
# Pulling: kucoin : RHOC/ETH [246/319]
# Pulling: kucoin : RPX/BTC [247/319]
# Pulling: kucoin : RPX/ETH [248/319]
# Pulling: kucoin : RPX/KCS [249/319]
# Pulling: kucoin : RPX/NEO [250/319]
# Pulling: kucoin : SNC/BTC [251/319]
# Pulling: kucoin : SNC/ETH [252/319]
# Pulling: kucoin : SNM/BTC [253/319]
# Pulling: kucoin : SNM/ETH [254/319]
# Pulling: kucoin : SNOV/BTC [255/319]
# Pulling: kucoin : SNOV/ETH [256/319]
# Pulling: kucoin : SNT/BTC [257/319]
# Pulling: kucoin : SNT/ETH [258/319]
# Pulling: kucoin : SPF/BTC [259/319]
# Pulling: kucoin : SPF/ETH [260/319]
# Pulling: kucoin : SPHTX/BTC [261/319]
# Pulling: kucoin : SPHTX/ETH [262/319]
# Pulling: kucoin : SRN/BTC [263/319]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 30 seconds...
# Pulling: kucoin : SRN-BTC [263/319]
# Got an error ExchangeError ('kucoin No market symbol SRN-BTC',) , retrying in 30 seconds...
# Pulling: kucoin : SRN-BTC [263/319]
# Got an error ExchangeError ('kucoin No market symbol SRN-BTC',) , retrying in 30 seconds...
# Pulling: kucoin : SRN-BTC [263/319]
# Got an error ExchangeError ('kucoin No market symbol SRN-BTC',) , retrying in 30 seconds...
# Pulling: kucoin : SRN-BTC [263/319]
# Got an error ExchangeError ('kucoin No market symbol SRN-BTC',) , retrying in 30 seconds...
# All attempts failed, skipping: SRN-BTC
# Pulling: kucoin : SRN/ETH [263/319]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 30 seconds...
# Pulling: kucoin : SRN-ETH [263/319]
# Got an error ExchangeError ('kucoin No market symbol SRN-ETH',) , retrying in 30 seconds...
# Pulling: kucoin : SRN-ETH [263/319]
# Got an error ExchangeError ('kucoin No market symbol SRN-ETH',) , retrying in 30 seconds...
# Pulling: kucoin : SRN-ETH [263/319]
# Got an error ExchangeError ('kucoin No market symbol SRN-ETH',) , retrying in 30 seconds...
# Pulling: kucoin : SRN-ETH [263/319]
# Got an error ExchangeError ('kucoin No market symbol SRN-ETH',) , retrying in 30 seconds...
# All attempts failed, skipping: SRN-ETH
# Pulling: kucoin : STK/BTC [263/319]
# Pulling: kucoin : STK/ETH [264/319]
# Pulling: kucoin : STX/BTC [265/319]
# Pulling: kucoin : STX/ETH [266/319]
# Pulling: kucoin : SUB/BTC [267/319]
# Pulling: kucoin : SUB/ETH [268/319]
# Pulling: kucoin : TEL/BTC [269/319]
# Pulling: kucoin : TEL/ETH [270/319]
# Pulling: kucoin : TFL/BTC [271/319]
# Pulling: kucoin : TFL/ETH [272/319]
# Pulling: kucoin : TIME/BTC [273/319]
# Pulling: kucoin : TIME/ETH [274/319]
# Pulling: kucoin : TIO/BTC [275/319]
# Pulling: kucoin : TIO/ETH [276/319]
# Pulling: kucoin : TKY/BTC [277/319]
# Pulling: kucoin : TKY/ETH [278/319]
# Pulling: kucoin : TKY/NEO [279/319]
# Pulling: kucoin : TKY/USDT [280/319]
# Pulling: kucoin : TNC/BTC [281/319]
# Pulling: kucoin : TNC/ETH [282/319]
# Pulling: kucoin : TNC/NEO [283/319]
# Pulling: kucoin : TOMO/BTC [284/319]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 30 seconds...
# Pulling: kucoin : TOMO-BTC [284/319]
# Got an error ExchangeError ('kucoin No market symbol TOMO-BTC',) , retrying in 30 seconds...
# Pulling: kucoin : TOMO-BTC [284/319]
# Got an error ExchangeError ('kucoin No market symbol TOMO-BTC',) , retrying in 30 seconds...
# Pulling: kucoin : TOMO-BTC [284/319]
# Got an error ExchangeError ('kucoin No market symbol TOMO-BTC',) , retrying in 30 seconds...
# Pulling: kucoin : TOMO-BTC [284/319]
# Got an error ExchangeError ('kucoin No market symbol TOMO-BTC',) , retrying in 30 seconds...
# All attempts failed, skipping: TOMO-BTC
# Pulling: kucoin : TOMO/ETH [284/319]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 30 seconds...
# Pulling: kucoin : TOMO-ETH [284/319]
# Got an error ExchangeError ('kucoin No market symbol TOMO-ETH',) , retrying in 30 seconds...
# Pulling: kucoin : TOMO-ETH [284/319]
# Got an error ExchangeError ('kucoin No market symbol TOMO-ETH',) , retrying in 30 seconds...
# Pulling: kucoin : TOMO-ETH [284/319]
# Got an error ExchangeError ('kucoin No market symbol TOMO-ETH',) , retrying in 30 seconds...
# Pulling: kucoin : TOMO-ETH [284/319]
# Got an error ExchangeError ('kucoin No market symbol TOMO-ETH',) , retrying in 30 seconds...
# All attempts failed, skipping: TOMO-ETH
# Pulling: kucoin : TRAC/BTC [284/319]
# Pulling: kucoin : TRAC/ETH [285/319]
# Pulling: kucoin : UKG/BTC [286/319]
# Pulling: kucoin : UKG/ETH [287/319]
# Pulling: kucoin : UTK/BTC [288/319]
# Pulling: kucoin : UTK/ETH [289/319]
# Pulling: kucoin : VEN/BTC [290/319]
# Pulling: kucoin : VEN/ETH [291/319]
# Pulling: kucoin : WAN/BTC [292/319]
# Pulling: kucoin : WAN/ETH [293/319]
# Pulling: kucoin : WAX/BTC [294/319]
# Pulling: kucoin : WAX/ETH [295/319]
# Pulling: kucoin : WPR/BTC [296/319]
# Pulling: kucoin : WPR/ETH [297/319]
# Pulling: kucoin : WTC/BTC [298/319]
# Pulling: kucoin : XAS/BTC [299/319]
# Pulling: kucoin : XAS/ETH [300/319]
# Pulling: kucoin : XLR/BTC [301/319]
# Pulling: kucoin : XLR/ETH [302/319]
# Pulling: kucoin : XRB/BTC [303/319]
# Pulling: kucoin : XRB/ETH [304/319]
# Pulling: kucoin : XRB/USDT [305/319]
# Pulling: kucoin : ZIL/BTC [306/319]
# Pulling: kucoin : ZIL/ETH [307/319]
# Pulling: kucoin : ZPT/BTC [308/319]
# Pulling: kucoin : ZPT/ETH [309/319]
# Pulling: kucoin : ZPT/NEO [310/319]
# Unable to obtain: ['BHC/BTC', 'BRD-BTC', 'BRD-ETH', 'MAN-BTC', 'MAN-ETH', 'SRN-BTC', 'SRN-ETH', 'TOMO-BTC', 'TOMO-ETH']
# Pulling: lbank : AAC/ETH [1/99]
# Pulling: lbank : AAC/QTUM [2/99]
# Pulling: lbank : ABT/BTC [3/99]
# Pulling: lbank : ABT/ETH [4/99]
# Pulling: lbank : BCD/BTC [5/99]
# Pulling: lbank : BCH/BTC [6/99]
# Got an error ExchangeError ('This currency pair is not supported',) , retrying in 30 seconds...
# Pulling: lbank : BCH/BTC [6/99]
# Got an error ExchangeError ('This currency pair is not supported',) , retrying in 30 seconds...
# Pulling: lbank : BCH/BTC [6/99]
# Got an error ExchangeError ('This currency pair is not supported',) , retrying in 30 seconds...
# Pulling: lbank : BCH/BTC [6/99]
# Got an error ExchangeError ('This currency pair is not supported',) , retrying in 30 seconds...
# Pulling: lbank : BCH/BTC [6/99]
# Got an error ExchangeError ('This currency pair is not supported',) , retrying in 30 seconds...
# All attempts failed, skipping: BCH/BTC
# Pulling: lbank : BCH/ETH [6/99]
# Got an error ExchangeError ('This currency pair is not supported',) , retrying in 30 seconds...
# Pulling: lbank : BCH/ETH [6/99]
# Got an error ExchangeError ('This currency pair is not supported',) , retrying in 30 seconds...
# Pulling: lbank : BCH/ETH [6/99]
# Got an error ExchangeError ('This currency pair is not supported',) , retrying in 30 seconds...
# Pulling: lbank : BCH/ETH [6/99]
# Got an error ExchangeError ('This currency pair is not supported',) , retrying in 30 seconds...
# Pulling: lbank : BCH/ETH [6/99]
# Got an error ExchangeError ('This currency pair is not supported',) , retrying in 30 seconds...
# All attempts failed, skipping: BCH/ETH
# Pulling: lbank : BCH/USDT [6/99]
# Got an error ExchangeError ('This currency pair is not supported',) , retrying in 30 seconds...
# Pulling: lbank : BCH/USDT [6/99]
# Got an error ExchangeError ('This currency pair is not supported',) , retrying in 30 seconds...
# Pulling: lbank : BCH/USDT [6/99]
# Got an error ExchangeError ('This currency pair is not supported',) , retrying in 30 seconds...
# Pulling: lbank : BCH/USDT [6/99]
# Got an error ExchangeError ('This currency pair is not supported',) , retrying in 30 seconds...
# Pulling: lbank : BCH/USDT [6/99]
# Got an error ExchangeError ('This currency pair is not supported',) , retrying in 30 seconds...
# All attempts failed, skipping: BCH/USDT
# Pulling: lbank : BOT/QTUM [6/99]
# Pulling: lbank : BSB/ETH [7/99]
# Pulling: lbank : BTC/USDT [8/99]
# Pulling: lbank : BTF/BTC [9/99]
# Pulling: lbank : BTG/BTC [10/99]
# Pulling: lbank : BTM/ETH [11/99]
# Pulling: lbank : BTO/ETH [12/99]
# Pulling: lbank : BTS/BTC [13/99]
# Pulling: lbank : BTS/ETH [14/99]
# Pulling: lbank : CDC/ETH [15/99]
# Pulling: lbank : CHAT/QTUM [16/99]
# Pulling: lbank : CMT/BTC [17/99]
# Pulling: lbank : CMT/ETH [18/99]
# Pulling: lbank : CPX/BTC [19/99]
# Pulling: lbank : CPX/ETH [20/99]
# Pulling: lbank : CPX/NEO [21/99]
# Pulling: lbank : CS/ETH [22/99]
# Pulling: lbank : DASH/BTC [23/99]
# Pulling: lbank : DAX/BTC [24/99]
# Pulling: lbank : DAX/ETH [25/99]
# Pulling: lbank : DAX/USDT [26/99]
# Pulling: lbank : DBC/ETH [27/99]
# Pulling: lbank : DBC/NEO [28/99]
# Pulling: lbank : DCT/ETH [29/99]
# Pulling: lbank : DDD/ETH [30/99]
# Pulling: lbank : DDM/ETH [31/99]
# Pulling: lbank : EAI/ETH [32/99]
# Pulling: lbank : EKO/ETH [33/99]
# Pulling: lbank : ENT/QTUM [34/99]
# Pulling: lbank : EOS/ETH [35/99]
# Pulling: lbank : ETC/BTC [36/99]
# Pulling: lbank : ETH/BTC [37/99]
# Pulling: lbank : ETH/USDT [38/99]
# Pulling: lbank : EXT/ETH [39/99]
# Pulling: lbank : EXT/NEO [40/99]
# Pulling: lbank : FIL12/BTC [41/99]
# Pulling: lbank : FIL12/ETH [42/99]
# Pulling: lbank : FIL36/BTC [43/99]
# Pulling: lbank : FIL36/ETH [44/99]
# Pulling: lbank : FIL6/BTC [45/99]
# Pulling: lbank : FIL6/ETH [46/99]
# Pulling: lbank : GRAMS/ETH [47/99]
# Pulling: lbank : IHT/ETH [48/99]
# Pulling: lbank : IIC/ETH [49/99]
# Pulling: lbank : INC/ETH [50/99]
# Pulling: lbank : INK/ETH [51/99]
# Pulling: lbank : INK/QTUM [52/99]
# Pulling: lbank : LCH/ETH [53/99]
# Pulling: lbank : LTC/BTC [54/99]
# Pulling: lbank : MAN/ETH [55/99]
# Pulling: lbank : MDA/ETH [56/99]
# Pulling: lbank : MITH/ETH [57/99]
# Pulling: lbank : MITH/QTUM [58/99]
# Pulling: lbank : NAS/ETH [59/99]
# Pulling: lbank : NEO/BTC [60/99]
# Pulling: lbank : NEO/USDT [61/99]
# Pulling: lbank : OCN/ETH [62/99]
# Pulling: lbank : PLY/ETH [63/99]
# Pulling: lbank : PLY/QTUM [64/99]
# Pulling: lbank : PNT/BTC [65/99]
# Pulling: lbank : PNT/ETH [66/99]
# Pulling: lbank : PST/ETH [67/99]
# Pulling: lbank : PTR/ETH [68/99]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 30 seconds...
# Pulling: lbank : PTR-ETH [68/99]
# Got an error ExchangeError ('lbank No market symbol PTR-ETH',) , retrying in 30 seconds...
# Pulling: lbank : PTR-ETH [68/99]
# Got an error ExchangeError ('lbank No market symbol PTR-ETH',) , retrying in 30 seconds...
# Pulling: lbank : PTR-ETH [68/99]
# Got an error ExchangeError ('lbank No market symbol PTR-ETH',) , retrying in 30 seconds...
# Pulling: lbank : PTR-ETH [68/99]
# Got an error ExchangeError ('lbank No market symbol PTR-ETH',) , retrying in 30 seconds...
# All attempts failed, skipping: PTR-ETH
# Pulling: lbank : PUT/ETH [68/99]
# Pulling: lbank : PUT/QTUM [69/99]
# Pulling: lbank : QBT/QTUM [70/99]
# Pulling: lbank : QTUM/BTC [71/99]
# Pulling: lbank : QTUM/ETH [72/99]
# Pulling: lbank : QTUM/USDT [73/99]
# Pulling: lbank : SBTC/BTC [74/99]
# Pulling: lbank : SC/BTC [75/99]
# Pulling: lbank : SEER/BTS [76/99]
# Pulling: lbank : SEER/ETH [77/99]
# Pulling: lbank : TGC/ETH [78/99]
# Pulling: lbank : TKY/ETH [79/99]
# Pulling: lbank : TKY/NEO [80/99]
# Pulling: lbank : TRX/ETH [81/99]
# Pulling: lbank : UIP/ETH [82/99]
# Pulling: lbank : VET/BTC [83/99]
# Got an error ExchangeError ('This currency pair is not supported',) , retrying in 30 seconds...
# Pulling: lbank : VET/BTC [83/99]
# Got an error ExchangeError ('This currency pair is not supported',) , retrying in 30 seconds...
# Pulling: lbank : VET/BTC [83/99]
# Got an error ExchangeError ('This currency pair is not supported',) , retrying in 30 seconds...
# Pulling: lbank : VET/BTC [83/99]
# Got an error ExchangeError ('This currency pair is not supported',) , retrying in 30 seconds...
# Pulling: lbank : VET/BTC [83/99]
# Got an error ExchangeError ('This currency pair is not supported',) , retrying in 30 seconds...
# All attempts failed, skipping: VET/BTC
# Pulling: lbank : VET/ETH [83/99]
# Got an error ExchangeError ('This currency pair is not supported',) , retrying in 30 seconds...
# Pulling: lbank : VET/ETH [83/99]
# Got an error ExchangeError ('This currency pair is not supported',) , retrying in 30 seconds...
# Pulling: lbank : VET/ETH [83/99]
# Got an error ExchangeError ('This currency pair is not supported',) , retrying in 30 seconds...
# Pulling: lbank : VET/ETH [83/99]
# Got an error ExchangeError ('This currency pair is not supported',) , retrying in 30 seconds...
# Pulling: lbank : VET/ETH [83/99]
# Got an error ExchangeError ('This currency pair is not supported',) , retrying in 30 seconds...
# All attempts failed, skipping: VET/ETH
# Pulling: lbank : VET/USDT [83/99]
# Got an error ExchangeError ('This currency pair is not supported',) , retrying in 30 seconds...
# Pulling: lbank : VET/USDT [83/99]
# Got an error ExchangeError ('This currency pair is not supported',) , retrying in 30 seconds...
# Pulling: lbank : VET/USDT [83/99]
# Got an error ExchangeError ('This currency pair is not supported',) , retrying in 30 seconds...
# Pulling: lbank : VET/USDT [83/99]
# Got an error ExchangeError ('This currency pair is not supported',) , retrying in 30 seconds...
# Pulling: lbank : VET/USDT [83/99]
# Got an error ExchangeError ('This currency pair is not supported',) , retrying in 30 seconds...
# All attempts failed, skipping: VET/USDT
# Pulling: lbank : XWC/BTC [83/99]
# Pulling: lbank : XWC/ETH [84/99]
# Pulling: lbank : YOYOW/BTS [85/99]
# Pulling: lbank : YOYOW/ETH [86/99]
# Pulling: lbank : ZEC/BTC [87/99]
# Pulling: lbank : ZEC/ETH [88/99]
# Pulling: lbank : ZEC/USDT [89/99]
# Pulling: lbank : ZPT/ETH [90/99]
# Pulling: lbank : ZPT/NEO [91/99]
# Pulling: lbank : ZSC/ETH [92/99]
# Unable to obtain: ['BCH/BTC', 'BCH/ETH', 'BCH/USDT', 'PTR-ETH', 'VET/BTC', 'VET/ETH', 'VET/USDT']

# %%
bittrex_w = ['XVC-BTC']
kraken_w = ['ETHCAD.d', 'ETHEUR.d', 'ETHGBP.d', 'ETHJPY.d', 'ETHUSD.d', 'ETHXBT.d', 'XBTCAD.d', 'XBTEUR.d', 'XBTGBP.d', 'XBTJPY.d', 'XBTUSD.d']
kucoin_w = ['BHC/BTC', 'BRD-BTC', 'BRD-ETH', 'MAN-BTC', 'MAN-ETH', 'SRN-BTC', 'SRN-ETH', 'TOMO-BTC', 'TOMO-ETH']
lbank_w = ['BCH/BTC', 'BCH/ETH', 'BCH/USDT', 'PTR-ETH', 'VET/BTC', 'VET/ETH', 'VET/USDT']

symbol_list_df('bittrex',bittrex_w,save=True,f_path='../symbols')
symbol_list_df('kraken',kraken_w,save=True,f_path='../symbols')
symbol_list_df('kucoin',kucoin_w,save=True,f_path='../symbols')
symbol_list_df('lbank',lbank_w,save=True,f_path='../symbols')
# Out:
# ['AAC/ETH',
#  'AAC/QTUM',
#  'ABT/BTC',
#  'ABT/ETH',
#  'BCD/BTC',
#  'BOT/QTUM',
#  'BSB/ETH',
#  'BTC/USDT',
#  'BTF/BTC',
#  'BTG/BTC',
#  'BTM/ETH',
#  'BTO/ETH',
#  'BTS/BTC',
#  'BTS/ETH',
#  'CDC/ETH',
#  'CHAT/QTUM',
#  'CMT/BTC',
#  'CMT/ETH',
#  'CPX/BTC',
#  'CPX/ETH',
#  'CPX/NEO',
#  'CS/ETH',
#  'DASH/BTC',
#  'DAX/BTC',
#  'DAX/ETH',
#  'DAX/USDT',
#  'DBC/ETH',
#  'DBC/NEO',
#  'DCT/ETH',
#  'DDD/ETH',
#  'DDM/ETH',
#  'EAI/ETH',
#  'EKO/ETH',
#  'ENT/QTUM',
#  'EOS/ETH',
#  'ETC/BTC',
#  'ETH/BTC',
#  'ETH/USDT',
#  'EXT/ETH',
#  'EXT/NEO',
#  'FIL12/BTC',
#  'FIL12/ETH',
#  'FIL36/BTC',
#  'FIL36/ETH',
#  'FIL6/BTC',
#  'FIL6/ETH',
#  'GRAMS/ETH',
#  'IHT/ETH',
#  'IIC/ETH',
#  'INC/ETH',
#  'INK/ETH',
#  'INK/QTUM',
#  'LCH/ETH',
#  'LTC/BTC',
#  'MAN/ETH',
#  'MDA/ETH',
#  'MITH/ETH',
#  'MITH/QTUM',
#  'NAS/ETH',
#  'NEO/BTC',
#  'NEO/USDT',
#  'OCN/ETH',
#  'PLY/ETH',
#  'PLY/QTUM',
#  'PNT/BTC',
#  'PNT/ETH',
#  'PST/ETH',
#  'PTR/ETH',
#  'PUT/ETH',
#  'PUT/QTUM',
#  'QBT/QTUM',
#  'QTUM/BTC',
#  'QTUM/ETH',
#  'QTUM/USDT',
#  'SBTC/BTC',
#  'SC/BTC',
#  'SEER/BTS',
#  'SEER/ETH',
#  'TGC/ETH',
#  'TKY/ETH',
#  'TKY/NEO',
#  'TRX/ETH',
#  'UIP/ETH',
#  'XWC/BTC',
#  'XWC/ETH',
#  'YOYOW/BTS',
#  'YOYOW/ETH',
#  'ZEC/BTC',
#  'ZEC/ETH',
#  'ZEC/USDT',
#  'ZPT/ETH',
#  'ZPT/NEO',
#  'ZSC/ETH']
